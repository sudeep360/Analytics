# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
biofuel=pd.read_csv('C:/Users/sudee/OneDrive/Desktop/FileExp/Renewable_Energy_Sheets/16 biofuel-production.csv')

# %%
biofuel.head(10)
# Out:
#         Entity Code  Year  Biofuels Production - TWh - Total
# 0  Africa (BP)  NaN  1990                           0.068617
# 1  Africa (BP)  NaN  1991                           0.068617
# 2  Africa (BP)  NaN  1992                           0.068805
# 3  Africa (BP)  NaN  1993                           0.068617
# 4  Africa (BP)  NaN  1994                           0.068617
# 5  Africa (BP)  NaN  1995                           0.068617
# 6  Africa (BP)  NaN  1996                           0.068805
# 7  Africa (BP)  NaN  1997                           0.102925
# 8  Africa (BP)  NaN  1998                           0.102925
# 9  Africa (BP)  NaN  1999                           0.068617

# %%
biofuel.set_index('Entity')
# Out:
#                  Code  Year  Biofuels Production - TWh - Total
# Entity
# Africa (BP)       NaN  1990                           0.068617
# Africa (BP)       NaN  1991                           0.068617
# Africa (BP)       NaN  1992                           0.068805
# Africa (BP)       NaN  1993                           0.068617
# Africa (BP)       NaN  1994                           0.068617
# ...               ...   ...                                ...
# World        OWID_WRL  2017                         968.131500
# World        OWID_WRL  2018                        1067.184900
# World        OWID_WRL  2019                        1114.488300
# World        OWID_WRL  2020                        1046.644300
# World        OWID_WRL  2021                        1083.607200
#
# [1081 rows x 3 columns]

# %% [markdown]
# # Biofuel Production

# %%
Aus_biofuel=biofuel.loc[biofuel['Entity']=='Australia']

# %%
Aus_biofuel
# Out:
#         Entity Code  Year  Biofuels Production - TWh - Total
# 86   Australia  AUS  1990                           0.000000
# 87   Australia  AUS  1991                           0.000000
# 88   Australia  AUS  1992                           0.000000
# 89   Australia  AUS  1993                           0.000000
# 90   Australia  AUS  1994                           0.000000
# 91   Australia  AUS  1995                           0.000000
# 92   Australia  AUS  1996                           0.000000
# 93   Australia  AUS  1997                           0.000000
# 94   Australia  AUS  1998                           0.000000
# 95   Australia  AUS  1999                           0.000000
# 96   Australia  AUS  2000                           0.000000
# 97   Australia  AUS  2001                           0.000000
# 98   Australia  AUS  2002                           0.000000
# 99   Australia  AUS  2003                           0.535323
# ...

# %%
subset_Aus_biofuel=Aus_biofuel.loc[99:117]
subset_Aus_biofuel
# Out:
#         Entity Code  Year  Biofuels Production - TWh - Total
# 99   Australia  AUS  2003                           0.535323
# 100  Australia  AUS  2004                           0.321809
# 101  Australia  AUS  2005                           0.320060
# 102  Australia  AUS  2006                           0.592059
# 103  Australia  AUS  2007                           1.159329
# 104  Australia  AUS  2008                           1.879363
# 105  Australia  AUS  2009                           2.695126
# 106  Australia  AUS  2010                           2.101782
# 107  Australia  AUS  2011                           2.542718
# 108  Australia  AUS  2012                           2.693399
# 109  Australia  AUS  2013                           2.845892
# 110  Australia  AUS  2014                           2.989948
# 111  Australia  AUS  2015                           2.640336
# 112  Australia  AUS  2016                           1.462265
# ...

# %%
subset_Aus_biofuel.plot(x='Year',y='Biofuels Production - TWh - Total')
# Out:
# <AxesSubplot:xlabel='Year'>
