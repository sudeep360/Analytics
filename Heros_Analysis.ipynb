# %%
import pandas as pd

# %%
hero_dc=pd.read_excel('superhero_info.xlsx',sheet_name='DC Comics')
hero_marvel=pd.read_excel('superhero_info.xlsx',sheet_name='Marvel Comics')

# %%
hero_powers=pd.read_csv('superhero_powers.csv')

# %%
hero_dc.head()
# Out:
#                 name Gender Eye color     Race Hair color  Height  Publisher  \
# 0           Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics
# 1       Adam Strange   Male      blue    Human      Blond     185  DC Comics
# 2         Alan Scott   Male      blue        -      Blond     180  DC Comics
# 3  Alfred Pennyworth   Male      blue    Human      Black     178  DC Comics
# 4              Amazo   Male       red  Android          -     257  DC Comics
#
#   Alignment  Weight
# 0      good    90.0
# 1      good    88.0
# 2      good    90.0
# 3      good    72.0
# 4       bad   173.0

# %%
hero_marvel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        388 non-null    object
#  1   Gender      388 non-null    object
#  2   Eye color   388 non-null    object
#  3   Race        388 non-null    object
#  4   Hair color  388 non-null    object
#  5   Height      388 non-null    int64
#  6   Publisher   388 non-null    object
#  7   Alignment   388 non-null    object
#  8   Weight      388 non-null    int64
# dtypes: int64(2), object(7)
# memory usage: 27.4+ KB

# %%
hero_powers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, hero_names to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %%
hero_powers.shape
# Out:
# (667, 168)

# %%
weather=pd.read_csv('weather.csv')

# %%
weather
# Out:
#          date  temperature_high temperature_low  rained  snowed overcast  \
# 0  2021-01-01               4.0               1       1   False   cloudy
# 1  2021-01-02              11.0               2       0   False    sunny
# 2  2021-01-03               3.0               2       0   False    foggy
# 3  2021-01-04               6.0               2       0   False    sunny
# 4  2021-01-05               4.0         unknown       0   False   cloudy
#
#               comments
# 0       happy new year
# 1           second day
# 2            third day
# 3   first business day
# 4  second business day

# %%
weather['temperature_high'].astype('int8')
# Out:
# 0     4
# 1    11
# 2     3
# 3     6
# 4     4
# Name: temperature_high, dtype: int8

# %%
weather['temperature_high']=weather['temperature_high'].astype('int8')

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              5 non-null      object
#  1   temperature_high  5 non-null      int8
#  2   temperature_low   5 non-null      object
#  3   rained            5 non-null      int64
#  4   snowed            5 non-null      bool
#  5   overcast          5 non-null      object
#  6   comments          5 non-null      object
# dtypes: bool(1), int64(1), int8(1), object(4)
# memory usage: 338.0+ bytes

# %%
weather['temperature_low'].astype('')
# Out:
# dtype('O')

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              5 non-null      object
#  1   temperature_high  5 non-null      float64
#  2   temperature_low   5 non-null      object
#  3   rained            5 non-null      int64
#  4   snowed            5 non-null      bool
#  5   overcast          5 non-null      object
#  6   comments          5 non-null      object
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 373.0+ bytes

# %%
weather['snowed']
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: snowed, dtype: bool

# %%
index_day=['sun','mon', 'tue', 'wed', 'thur']

# %%
weather_new=weather.set_index(pd.Index(index_day))

# %%
weather_new
# Out:
#             date  temperature_high temperature_low  rained  snowed overcast  \
# sun   2021-01-01               4.0               1       1   False   cloudy
# mon   2021-01-02              11.0               2       0   False    sunny
# tue   2021-01-03               3.0               2       0   False    foggy
# wed   2021-01-04               6.0               2       0   False    sunny
# thur  2021-01-05               4.0         unknown       0   False   cloudy
#
#                  comments
# sun        happy new year
# mon            second day
# tue             third day
# wed    first business day
# thur  second business day

# %%
weather
# Out:
#          date  temperature_high temperature_low  rained  snowed overcast  \
# 0  2021-01-01               4.0               1       1   False   cloudy
# 1  2021-01-02              11.0               2       0   False    sunny
# 2  2021-01-03               3.0               2       0   False    foggy
# 3  2021-01-04               6.0               2       0   False    sunny
# 4  2021-01-05               4.0         unknown       0   False   cloudy
#
#               comments
# 0       happy new year
# 1           second day
# 2            third day
# 3   first business day
# 4  second business day

# %% [markdown]
# ## COMBINING DATASETS

# %%
import pandas as pd

# %%
hero_dc=pd.read_excel('superhero_info.xlsx',sheet_name='DC Comics')
hero_marvel=pd.read_excel('superhero_info.xlsx',sheet_name='Marvel Comics')

# %%
hero_dc
# Out:
#                   name  Gender Eye color      Race Hair color  Height  \
# 0             Abin Sur    Male      blue   Ungaran    No Hair     185
# 1         Adam Strange    Male      blue     Human      Blond     185
# 2           Alan Scott    Male      blue         -      Blond     180
# 3    Alfred Pennyworth    Male      blue     Human      Black     178
# 4                Amazo    Male       red   Android          -     257
# ..                 ...     ...       ...       ...        ...     ...
# 210           Wildfire    Male         -         -          -     -99
# 211        Wonder Girl  Female      blue  Demi-God      Blond     165
# 212       Wonder Woman  Female      blue    Amazon      Black     183
# 213            Zatanna  Female      blue     Human      Black     170
# 214               Zoom    Male       red         -      Brown     185
#
#      Publisher Alignment  Weight
# 0    DC Comics      good    90.0
# 1    DC Comics      good    88.0
# ...

# %%
hero_marvel
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1        Abomination    Male     green  Human / Radiation           No Hair
# 2            Abraxas    Male      blue      Cosmic Entity             Black
# 3      Absorbing Man    Male      blue              Human           No Hair
# 4           Agent 13  Female      blue                  -             Blond
# ..               ...     ...       ...                ...               ...
# 383            X-Man    Male      blue                  -             Brown
# 384      Yellow Claw    Male      blue                  -           No Hair
# 385     Yellowjacket    Male      blue              Human             Blond
# 386  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 387             Ymir    Male     white        Frost Giant           No Hair
#
#      Height      Publisher Alignment  Weight
# ...

# %%
215+388
# Out:
# 603

# %%
hero_new=pd.merge(hero_dc,hero_marvel,how='inner')

# %%
hero_new
# Out:
#              name Gender_x Eye color_x         Race_x Hair color_x  Height_x  \
# 0           Atlas     Male        blue  God / Eternal        Brown       198
# 1  Captain Marvel     Male        blue          Human        Black       193
#
#   Publisher_x Alignment_x  Weight_x Gender_y Eye color_y      Race_y  \
# 0   DC Comics         bad     126.0     Male       brown      Mutant
# 1   DC Comics        good     101.0   Female        blue  Human-Kree
#
#   Hair color_y  Height_y    Publisher_y Alignment_y  Weight_y
# 0          Red       183  Marvel Comics        good       101
# 1        Blond       180  Marvel Comics        good        74

# %%
hero_new.sort_values(by='name')
# Out:
#              name Gender_x Eye color_x         Race_x Hair color_x  Height_x  \
# 0           Atlas     Male        blue  God / Eternal        Brown       198
# 1  Captain Marvel     Male        blue          Human        Black       193
#
#   Publisher_x Alignment_x  Weight_x Gender_y Eye color_y      Race_y  \
# 0   DC Comics         bad     126.0     Male       brown      Mutant
# 1   DC Comics        good     101.0   Female        blue  Human-Kree
#
#   Hair color_y  Height_y    Publisher_y Alignment_y  Weight_y
# 0          Red       183  Marvel Comics        good       101
# 1        Blond       180  Marvel Comics        good        74

# %%
table1=pd.DataFrame({'a':[1,2,3,4,5], 'b':['m','n','o','p','q']})

# %%
dict2={'a':[4,5,6,7,8],
 'x':['s','t','u','v','w']}

# %%
table2=pd.DataFrame(dict2, index=['March','Apr','Jun','Jul','Aug'])
table2
# Out:
#        a  x
# March  4  s
# Apr    5  t
# Jun    6  u
# Jul    7  v
# Aug    8  w

# %%
pd.merge(table1,table2,on='a',how='outer')
# Out:
#    a    b    x
# 0  1    m  NaN
# 1  2    n  NaN
# 2  3    o  NaN
# 3  4    p    s
# 4  5    q    t
# 5  6  NaN    u
# 6  7  NaN    v
# 7  8  NaN    w

# %%
hero_new
# Out:
#              name Gender_x Eye color_x         Race_x Hair color_x  Height_x  \
# 0           Atlas     Male        blue  God / Eternal        Brown       198
# 1  Captain Marvel     Male        blue          Human        Black       193
#
#   Publisher_x Alignment_x  Weight_x Gender_y Eye color_y      Race_y  \
# 0   DC Comics         bad     126.0     Male       brown      Mutant
# 1   DC Comics        good     101.0   Female        blue  Human-Kree
#
#   Hair color_y  Height_y    Publisher_y Alignment_y  Weight_y
# 0          Red       183  Marvel Comics        good       101
# 1        Blond       180  Marvel Comics        good        74

# %%
del hero_new

# %%
hero_new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23712\502626096.py in <module>
# ----> 1 hero_new
#
# NameError: name 'hero_new' is not defined

# %%
hero_dc.to_pickle('hero_dc.pkl')
hero_marvel.to_pickle('hero_marvel.pkl')
hero_powers.to_pickle('hero_powers.pkl')

# %%
hero_dc=pd.read_pickle('hero_dc.pkl')
hero_marvel=pd.read_pickle('hero_marvel.pkl')
hero_powers=pd.read_pickle('hero_powers.pkl')

# %%
hero_info=pd.concat([hero_dc,hero_marvel],ignore_index=True)
hero_info
# Out:
#                   name  Gender Eye color         Race        Hair color  \
# 0             Abin Sur    Male      blue      Ungaran           No Hair
# 1         Adam Strange    Male      blue        Human             Blond
# 2           Alan Scott    Male      blue            -             Blond
# 3    Alfred Pennyworth    Male      blue        Human             Black
# 4                Amazo    Male       red      Android                 -
# ..                 ...     ...       ...          ...               ...
# 598              X-Man    Male      blue            -             Brown
# 599        Yellow Claw    Male      blue            -           No Hair
# 600       Yellowjacket    Male      blue        Human             Blond
# 601    Yellowjacket II  Female      blue        Human  Strawberry Blond
# 602               Ymir    Male     white  Frost Giant           No Hair
#
#      Height      Publisher Alignment  Weight
# 0       185      DC Comics      good    90.0
# ...

# %%
import numpy as np

# %%
hero_info.index=np.arange(1,len(hero_info)+1)
hero_info
# Out:
#                   name  Gender Eye color         Race        Hair color  \
# 1             Abin Sur    Male      blue      Ungaran           No Hair
# 2         Adam Strange    Male      blue        Human             Blond
# 3           Alan Scott    Male      blue            -             Blond
# 4    Alfred Pennyworth    Male      blue        Human             Black
# 5                Amazo    Male       red      Android                 -
# ..                 ...     ...       ...          ...               ...
# 599              X-Man    Male      blue            -             Brown
# 600        Yellow Claw    Male      blue            -           No Hair
# 601       Yellowjacket    Male      blue        Human             Blond
# 602    Yellowjacket II  Female      blue        Human  Strawberry Blond
# 603               Ymir    Male     white  Frost Giant           No Hair
#
#      Height      Publisher Alignment  Weight
# 1       185      DC Comics      good    90.0
# ...

# %%
hero_info.sort_values(by='name')
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 216           A-Bomb    Male    yellow              Human           No Hair
# 1           Abin Sur    Male      blue            Ungaran           No Hair
# 217      Abomination    Male     green  Human / Radiation           No Hair
# 218          Abraxas    Male      blue      Cosmic Entity             Black
# 219    Absorbing Man    Male      blue              Human           No Hair
# ..               ...     ...       ...                ...               ...
# 601     Yellowjacket    Male      blue              Human             Blond
# 602  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 603             Ymir    Male     white        Frost Giant           No Hair
# 214          Zatanna  Female      blue              Human             Black
# 215             Zoom    Male       red                  -             Brown
#
#      Height      Publisher Alignment  Weight
# ...

# %%
hero_info
# Out:
#                   name  Gender Eye color         Race        Hair color  \
# 1             Abin Sur    Male      blue      Ungaran           No Hair
# 2         Adam Strange    Male      blue        Human             Blond
# 3           Alan Scott    Male      blue            -             Blond
# 4    Alfred Pennyworth    Male      blue        Human             Black
# 5                Amazo    Male       red      Android                 -
# ..                 ...     ...       ...          ...               ...
# 599              X-Man    Male      blue            -             Brown
# 600        Yellow Claw    Male      blue            -           No Hair
# 601       Yellowjacket    Male      blue        Human             Blond
# 602    Yellowjacket II  Female      blue        Human  Strawberry Blond
# 603               Ymir    Male     white  Frost Giant           No Hair
#
#      Height      Publisher Alignment  Weight
# 1       185      DC Comics      good    90.0
# ...

# %%
#hero_dc.head(1)
#hero_marvel.head(1)
#hero_powers.head(1)
hero_info
# Out:
#                   name  Gender Eye color         Race        Hair color  \
# 1             Abin Sur    Male      blue      Ungaran           No Hair
# 2         Adam Strange    Male      blue        Human             Blond
# 3           Alan Scott    Male      blue            -             Blond
# 4    Alfred Pennyworth    Male      blue        Human             Black
# 5                Amazo    Male       red      Android                 -
# ..                 ...     ...       ...          ...               ...
# 599              X-Man    Male      blue            -             Brown
# 600        Yellow Claw    Male      blue            -           No Hair
# 601       Yellowjacket    Male      blue        Human             Blond
# 602    Yellowjacket II  Female      blue        Human  Strawberry Blond
# 603               Ymir    Male     white  Frost Giant           No Hair
#
#      Height      Publisher Alignment  Weight
# 1       185      DC Comics      good    90.0
# ...

# %%
hero=pd.merge(hero_info,hero_powers,left_on='name',right_on='hero_names',how='left')#'name',right_on='hero_names',how='inner')

# %%
hero
# Out:
#                   name  Gender Eye color         Race        Hair color  \
# 0             Abin Sur    Male      blue      Ungaran           No Hair
# 1         Adam Strange    Male      blue        Human             Blond
# 2           Alan Scott    Male      blue            -             Blond
# 3    Alfred Pennyworth    Male      blue        Human             Black
# 4                Amazo    Male       red      Android                 -
# ..                 ...     ...       ...          ...               ...
# 598              X-Man    Male      blue            -             Brown
# 599        Yellow Claw    Male      blue            -           No Hair
# 600       Yellowjacket    Male      blue        Human             Blond
# 601    Yellowjacket II  Female      blue        Human  Strawberry Blond
# 602               Ymir    Male     white  Frost Giant           No Hair
#
#      Height      Publisher Alignment  Weight       hero_names  ...  \
# ...

# %%
hero.shape
# Out:
# (537, 177)

# %%
hero.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 0 to 602
# Data columns (total 177 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    name                          object
#  1    Gender                        object
#  2    Eye color                     object
#  3    Race                          object
#  4    Hair color                    object
#  5    Height                        int64
#  6    Publisher                     object
#  7    Alignment                     object
#  8    Weight                        float64
#  9    hero_names                    object
#  10   Agility                       object
#  11   Accelerated Healing           object
#  12   Lantern Power Ring            object
#  13   Dimensional Awareness         object
#  14   Cold Resistance               object
#  15   Durability                    object
#  16   Stealth                       object
# ...
